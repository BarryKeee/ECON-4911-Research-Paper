# %%
import os
from os import listdir
from os.path import isfile, join
R1000_file = './russell/1000'
R2000_file = './russell/2000'

# %%
R1000_filename= os.listdir(R1000_file)
R2000_filename=os.listdir(R2000_file)

# %%
import sys

# %%
import pandas as pd

# %%
R1000_list = pd.DataFrame(columns = ['Year','Ticker','Price'])
for file in R1000_filename:
    temp = pd.read_excel(os.path.join(os.getcwd(), R1000_file, file))
    temp = temp[['Ticker','Price']]
    temp['Ticker'] = temp['Ticker'].apply(lambda x: x[:-9])
    temp['Year'] = file[-10:-6]
    R1000_list = R1000_list.append(temp, ignore_index = True)
# Out:
# C:\Users\barry\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
R2000_list = pd.DataFrame(columns = ['Year','Ticker','Price'])
for file in R2000_filename:
    temp = pd.read_excel(os.path.join(os.getcwd(), R2000_file, file))
    temp = temp[['Ticker','Price']]
    temp['Ticker'] = temp['Ticker'].apply(lambda x: x[:-9])
    temp['Year'] = file[-10:-6]
    R2000_list = R2000_list.append(temp, ignore_index = True)
# Out:
# C:\Users\barry\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
R2000_list.sort_values('Year')['Ticker'].unique().shape
# Out:
# (7066,)

# %%
IO = pd.read_csv('13F.csv')
# Out:
# C:\Users\barry\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (7,16,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
R2000_list['Membership'] = 'R2000'
R1000_list['Membership'] = 'R1000'

Russell_all = R1000_list.append(R2000_list, ignore_index = True)

# %%
IO_russell = IO[IO['ticker'].apply(lambda x: x in Russell_ all['Ticker'].unique())]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7cba02188110> in <module>()
# ----> 1 IO_russell = IO[IO['ticker'].apply(lambda x: x in Russell_all['Ticker'].unique())]
#
# C:\Users\barry\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-16-7cba02188110> in <lambda>(x)
# ----> 1 IO_russell = IO[IO['ticker'].apply(lambda x: x in Russell_all['Ticker'].unique())]
#
# C:\Users\barry\Anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    1489         Categories (3, object): [a < b < c]
#    1490         """
# -> 1491         result = super(Series, self).unique()
#    1492
#    1493         if is_datetime64tz_dtype(self.dtype):
#
# C:\Users\barry\Anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#    1047         else:
#    1048             from pandas.core.algorithms import unique1d
# -> 1049             result = unique1d(values)
#    1050
#    1051         return result
#
# C:\Users\barry\Anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     366
#     367     table = htable(len(values))
# --> 368     uniques = table.unique(values)
#     369     uniques = _reconstruct_data(uniques, dtype, original)
#     370
#
# KeyboardInterrupt:

# %%
IO.head()
# Out:
#       fdate                       mgrname country  mgrno  typecode     rdate  \
# 0  20000331      ADVENT CAPITAL MANGEMENT     NaN    483         5  20000331
# 1  20000331   M & I INVESTMENT MGMT CORP.     NaN  54280         5  20000331
# 2  20000331              ADVEST GROUP INC     NaN    485         4  20000331
# 3  20000331             BARCLAYS BANK PLC     NaN   7900         4  20000331
# 4  20000331  BRIDGEWAY CAPITAL MGMT, INC.     NaN  10042         5  20000331
#
#    prdate     cusip   shares  sole   ...      change      stkname  ticker  \
# 0     NaN       NaN      NaN   NaN   ...         NaN          NaN     NaN
# 1     NaN  00035730  11405.0   NaN   ...         NaN  AAL MUT FDS    AAMB
# 2     NaN  00036020  10500.0   NaN   ...         NaN     AAON INC    AAON
# 3     NaN  00036020  85196.0   NaN   ...       300.0     AAON INC    AAON
# 4     NaN  00036020  50900.0   NaN   ...     50900.0     AAON INC    AAON
#
#   exchcd stkcd indcode stkcdesc    prc shrout1  shrout2
# 0    NaN   NaN     NaN      NaN    NaN     NaN      NaN
# 1    NaN   NaN     NaN      NaN  10.81     NaN      NaN
# 2    NaN   NaN     NaN      NaN  17.56     6.0      NaN
# 3    NaN   NaN     NaN      NaN  17.56     6.0      NaN
# 4    NaN   NaN     NaN      NaN  17.56     6.0      NaN
#
# [5 rows x 22 columns]

# %%
IO[['fdate','ticker']]
pd.MultiIndex(levels = ['year','ticker'], )

# %%
IO.set_index(['fdate','ticker'], inplace = True)

# %%
group = IO.groupby(['fdate','ticker'])

# %%
IO.head()
# Out:
#                                       mgrname country  mgrno  typecode  \
# fdate    ticker
# 20000331 NaN         ADVENT CAPITAL MANGEMENT     NaN    483         5
#          AAMB     M & I INVESTMENT MGMT CORP.     NaN  54280         5
#          AAON                ADVEST GROUP INC     NaN    485         4
#          AAON               BARCLAYS BANK PLC     NaN   7900         4
#          AAON    BRIDGEWAY CAPITAL MGMT, INC.     NaN  10042         5
#
#                     rdate  prdate     cusip   shares  sole  shared  no  \
# fdate    ticker
# 20000331 NaN     20000331     NaN       NaN      NaN   NaN     NaN NaN
#          AAMB    20000331     NaN  00035730  11405.0   NaN     NaN NaN
#          AAON    20000331     NaN  00036020  10500.0   NaN     NaN NaN
#          AAON    20000331     NaN  00036020  85196.0   NaN     NaN NaN
#          AAON    20000331     NaN  00036020  50900.0   NaN     NaN NaN
#
#                   change      stkname exchcd stkcd  indcode stkcdesc    prc  \
# fdate    ticker
# 20000331 NaN         NaN          NaN    NaN   NaN      NaN      NaN    NaN
#          AAMB        NaN  AAL MUT FDS    NaN   NaN      NaN      NaN  10.81
#          AAON        NaN     AAON INC    NaN   NaN      NaN      NaN  17.56
#          AAON      300.0     AAON INC    NaN   NaN      NaN      NaN  17.56
#          AAON    50900.0     AAON INC    NaN   NaN      NaN      NaN  17.56
#
#                  shrout1  shrout2
# fdate    ticker
# 20000331 NaN         NaN      NaN
#          AAMB        NaN      NaN
#          AAON        6.0      NaN
#          AAON        6.0      NaN
#          AAON        6.0      NaN

# %%
IO_shares = group.sum()['shares']

# %%
IO_total_share = group.first()[['prc','shrout1','shrout2']]

# %%
IO_percent = IO_shares / (IO_total_share['shrout1']*1000000)
IO_mktcap = IO_total_share['prc']*IO_total_share['shrout1']*1000000

# %%
import numpy as np
IO_percent_clean = IO_percent.replace(np.inf,np.nan).dropna()

# %%
IO_output = IO_percent_clean.reset_index()
IO_output.columns = ['Date','Ticker','IO']
IO_output.to_excel('IO_output.xlsx')

# %%
IO_count = group.count()['shares']

# %%
IO_count.replace(0, np.nan).dropna()
# Out:
# fdate     ticker
# 20000331  A         186
#           AA        485
#           AAAB        3
#           AABC        4
#           AAC        49
#           AACB       13
#           AACE       20
#           AAG        31
#           AAG/        1
#           AAGF        2
#           AAGP        3
#           AAI         1
#           AAIE        1
#           AAII       25
#           AAIR       55
#           AAM        25
#           AAMB        1
#           AAME        9
#           AANB        4
#           AAON       10
#           AAP         6
#           AAPL      367
#           AAPT        1
#           AAS       101
#           AASA        2
#           AASI        7
#           AASP        1
#           AASR        2
#           AAT        10
#           AATK        6
#                    ...
# 20180630  YLCO       11
#           YLD         4
#           YLDE        4
#           YMLI       18
#           YMLP       24
#           YORW      100
#           YPF       138
#           YRI       228
#           YUEI        1
#           YUII        1
#           YUM       913
#           YXI         6
#           YYY        28
#           YZC         1
#           ZAGG      148
#           ZBH       871
#           ZBIO        7
#           ZBRA      400
#           ZBpA        3
#           ZEUS      102
#           ZION      552
#           ZIOP      130
#           ZIXI      127
#           ZMLP       17
#           ZN         61
#           ZNH        41
#           ZROZ       28
#           ZSL        12
#           ZUMZ      161
#           ZYXI        1
# Name: shares, Length: 709022, dtype: int64

# %%
IO_sum = pd.DataFrame(index = IO_count.index, columns = ['count','percent','mktcap'])
IO_sum['count'] = IO_count
IO_sum['percent'] = IO_percent
IO_sum['mktcap'] = IO_mktcap

# %%
IO_sum.replace(np.inf, np.nan).dropna().reset_index().to_excel('IO_output.xlsx')

# %%
IO_sum = pd.read_excel('IO_output.xlsx')

# %%
IO_sum = IO_sum[IO_sum['percent'] <= 1]

# %%
print(IO_sum.describe().round(2).to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &      count &    percent &        mktcap \\
# \midrule
# count &  566071.00 &  566071.00 &  5.660710e+05 \\
# mean  &      81.63 &       0.30 &  7.461152e+09 \\
# std   &     163.00 &       0.32 &  1.302741e+11 \\
# min   &       1.00 &       0.00 &  0.000000e+00 \\
# 25\%   &       3.00 &       0.01 &  3.499000e+07 \\
# 50\%   &      21.00 &       0.17 &  1.972800e+08 \\
# 75\%   &      92.00 &       0.56 &  1.269390e+09 \\
# max   &    2793.00 &       1.00 &  2.147614e+13 \\
# \bottomrule
# \end{tabular}

# %%
def wavg(group, avg_name, weight_name):
    
    d = group[avg_name]
    w = group[weight_name]
    try:
        return (d * w).sum() / w.sum()
    except ZeroDivisionError:
        return d.mean()

# %%
IO_sum.groupby('fdate').apply(wavg, 'percent', 'mktcap').plot()

# %%
import matplotlib.pyplot as plt

% matplotlib notebook

# %%
from dateutil.parser import parse
IO_sum['fdate'] = IO_sum['fdate'].apply(lambda x: parse(str(x)))

# %%
def wavg(group, avg_name, weight_name):
    d = group[avg_name]
    w = group[weight_name]
    try:
        return (d * w).sum() / w.sum()
    except ZeroDivisionError:
        return d.mean()

# %%
fig= plt.figure(figsize = (10,6))
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx()
IO_sum.groupby('fdate').mean()['count'].plot(color = 'grey',ax = ax2,label = 'Count of institutional owners')
IO_sum.groupby('fdate').mean()['percent'].plot(kind = 'line',ax = ax1,label = 'Percent of institutional ownership')
#IO_sum.groupby('fdate').apply(wavg, 'percent','mktcap').plot(kind = 'line',ax = ax1,label = 'Percent of institutional ownership')
ax2.set_xlabel('Year')
ax2.set_ylabel('Count')
ax1.set_xlabel('Year')
ax1.set_ylabel('Value')
ax1.legend(loc = 2)
ax2.legend(loc = 4)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Covariates summary

# %%
russell_cov = pd.read_csv('russell_tic_cov.csv')

# %%
russell_cov = russell_cov[['datadate','fyear','tic','csho','ni','revt','prcc_f']]

# %%
russell_cov['mktcap'] = russell_cov['csho']*russell_cov['prcc_f']
# Out:
# C:\Users\barry\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cov_sum = russell_cov.describe().round(2)
cov_sum['IO_count'] = IO_sum.describe().round(2)['count']
cov_sum['IO_percent'] = IO_sum.describe().round(2)['percent']
print(cov_sum.T.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &     count &         mean &       std &          min &          25\% &          50\% &          75\% &          max \\
# \midrule
# datadate   &   65373.0 &  20090315.56 &  53887.56 &  20000630.00 &  20041231.00 &  20091231.00 &  20140630.00 &  20190228.00 \\
# fyear      &   65373.0 &      2008.83 &      5.39 &      2000.00 &      2004.00 &      2009.00 &      2014.00 &      2018.00 \\
# csho       &   65333.0 &       134.29 &    486.35 &         0.24 &        19.60 &        40.38 &        92.36 &     29058.36 \\
# ni         &   65298.0 &       215.18 &   1609.12 &    -99289.00 &        -5.51 &        18.13 &       102.30 &     59531.00 \\
# revt       &   65298.0 &      3408.37 &  14391.03 &     -4234.47 &       109.07 &       440.81 &      1776.41 &    514405.00 \\
# prcc\_f     &   65372.0 &        29.34 &     62.96 &         0.00 &         8.36 &        18.86 &        35.55 &      4410.00 \\
# mktcap     &   65332.0 &      5046.16 &  22548.42 &         0.00 &       195.93 &       647.29 &      2405.13 &   1073390.54 \\
# IO\_count   &  566071.0 &        81.63 &    163.00 &         1.00 &         3.00 &        21.00 &        92.00 &      2793.00 \\
# IO\_percent &  566071.0 &         0.30 &      0.32 &         0.00 &         0.01 &         0.17 &         0.56 &         1.00 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ExecuComp Summary

# %%
ExecuComp = pd.read_csv('ExecuComp_annual.csv', encoding = 'latin-1')

# %%
ExecuComp.columns
ExecuComp['year'] = ExecuComp['YEAR'].apply(lambda x: parse(str(x)))

# %%
print(ExecuComp.drop(66797).drop(73731)[['SALARY','BONUS','STOCK_AWARDS','OPTION_AWARDS','OTHCOMP','LTIP','RSTKGRNT','TDC1']].describe().round(2).T.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &     count &     mean &      std &      min &     25\% &      50\% &      75\% &         max \\
# \midrule
# SALARY        &  199622.0 &   451.47 &   312.43 &    -0.00 &  262.50 &   375.00 &   550.70 &     8319.74 \\
# BONUS         &  199622.0 &   222.60 &   913.75 &   -16.50 &    0.00 &     0.00 &   170.00 &   121271.35 \\
# STOCK\_AWARDS  &  131512.0 &  1030.97 &  5961.11 & -7230.19 &   41.44 &   347.98 &  1046.26 &  1927510.71 \\
# OPTION\_AWARDS &  131512.0 &   454.40 &  1668.22 & -3330.97 &    0.00 &    55.95 &   390.13 &   115884.00 \\
# OTHCOMP       &  199622.0 &   162.37 &  1107.99 & -4901.33 &    9.27 &    28.13 &    84.85 &   203641.00 \\
# LTIP          &   68110.0 &    90.23 &   691.88 &  -682.52 &    0.00 &     0.00 &     0.00 &    84799.99 \\
# RSTKGRNT      &   68110.0 &   275.28 &  1297.85 &     0.00 &    0.00 &     0.00 &    67.38 &    74750.00 \\
# TDC1          &  184673.0 &  2710.63 &  5213.57 & -5172.15 &  704.72 &  1399.94 &  2910.25 &   600347.35 \\
# \bottomrule
# \end{tabular}

# %%
execu_plot = ExecuComp.drop(66797).drop(73731).groupby('year').mean()[['SALARY','BONUS','STOCK_AWARDS','OPTION_AWARDS','OTHCOMP','LTIP','RSTKGRNT']]
fig = plt.figure(figsize = (10,6))

plt.plot(execu_plot['SALARY'], label='Salary')
plt.plot(execu_plot['BONUS'], label='Bonus')
plt.plot(execu_plot['STOCK_AWARDS'], label='Stock Award')
plt.plot(execu_plot['OPTION_AWARDS'], label='Option Award')
plt.plot(execu_plot['OTHCOMP'], label='Other')
plt.plot(execu_plot['LTIP'], label='LTIP')
plt.plot(execu_plot['RSTKGRNT'], label='Restricted Stock Grant')
plt.legend(loc = 2)

plt.ylabel('Value (in thousand USD)')
plt.xlabel('Year')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,0,'Year')

# %%
ExecuComp = ExecuComp.drop(66797).drop(73731)

# %%
ExecuComp_mean = ExecuComp.groupby(['year','TICKER']).mean()

# %%
pd.DatetimeIndex(ExecuComp_mean.reset_index()['year']).year
# Out:
# Int64Index([2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000,
#             ...
#             2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018],
#            dtype='int64', name='year', length=35499)

# %%
IO_sum['year'] = pd.DatetimeIndex(IO_sum['fdate']).year

# %%
IO_sum_sum = IO_sum.set_index(['year','ticker'])

# %%
IO_sum_sum = IO_sum_sum.groupby(['year','ticker']).mean()

# %%
russell_cov['year'] = russell_cov['fyear'].apply(lambda x: parse(str(x)))
# Out:
# C:\Users\barry\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
russell_cov['year'] = pd.DatetimeIndex(russell_cov['year']).year
# Out:
# C:\Users\barry\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
russell_cov_fix = russell_cov.groupby(['year','tic']).first()
russell_cov_fix['IO_percent'] = IO_sum_sum['percent']*100
russell_cov_fix['IO_count'] = IO_sum_sum['count']

# %%
execucomp_panel = russell_cov_fix

# %%
ExecuComp_mean = ExecuComp_mean.reset_index()
ExecuComp_mean['year'] = pd.DatetimeIndex(ExecuComp_mean.reset_index()['year']).year

# %%
ExecuComp_mean
# Out:
#        year  TICKER  EXECRANK    CO_PER_ROL       SALARY        BONUS  \
# 0      2000   0015B       NaN  20211.000000   257.451000     2.000000
# 1      2000   0033A       NaN  13639.500000   605.277833   189.166667
# 2      2000   0059A       NaN  14347.800000   518.591600   402.964600
# 3      2000   0083A  4.000000  23520.833333   480.833333   461.833333
# 4      2000   0090A       NaN  20732.000000   370.093375   517.500000
# 5      2000   0139A       NaN  15876.111111   373.000000   496.214000
# 6      2000   0154A  2.500000  18059.800000   134.500000    27.800000
# 35492  2018     TPR  2.000000  53162.000000   926.000000   345.000000
# 35493  2018    TUES       NaN  53602.200000   408.200000     0.000000
# 35494  2018     UFI  4.000000  52835.500000   474.170500     1.666667
# 35495  2018    UNFI       NaN  48729.500000   525.729667     0.000000
# 35496  2018     WDC  5.000000  50665.666667   734.985833     0.000000
# 35497  2018    WDFC       NaN  36062.400000   376.759200     0.000000
# 35498  2018     WGO  5.000000  56227.600000   451.796400    10.000000
#
#        STOCK_AWARDS  OPTION_AWARDS     OTHCOMP     TOTAL_SEC   ...     \
# 0               NaN            NaN   14.137400           NaN   ...
# 1               NaN            NaN  123.018500           NaN   ...
# 2               NaN            NaN    6.000000           NaN   ...
# 3               NaN            NaN   33.368000           NaN   ...
# 4               NaN            NaN   27.552125           NaN   ...
# 5               NaN            NaN   12.659222           NaN   ...
# 6               NaN            NaN   26.200000           NaN   ...
# 7               NaN            NaN   40.276375           NaN   ...
# 8               NaN            NaN    7.311000           NaN   ...
# 9               NaN            NaN   77.344000           NaN   ...
# 10              NaN            NaN   40.271625           NaN   ...
# 11              NaN            NaN  116.425833           NaN   ...
# 12              NaN            NaN   24.987333           NaN   ...
# 13              NaN            NaN   51.881200           NaN   ...
# 14              NaN            NaN   21.167375           NaN   ...
# 15              NaN            NaN  114.841333           NaN   ...
# 16              NaN            NaN   12.479625           NaN   ...
# 17              NaN            NaN  103.427800           NaN   ...
# 18              NaN            NaN   24.384111           NaN   ...
# 19              NaN            NaN   20.402750           NaN   ...
# 20              NaN            NaN    0.000000           NaN   ...
# 21              NaN            NaN   27.175167           NaN   ...
# 22              NaN            NaN  187.917667           NaN   ...
# 23              NaN            NaN  716.284875           NaN   ...
# 24              NaN            NaN   23.502333           NaN   ...
# 25              NaN            NaN   87.286167           NaN   ...
# 26              NaN            NaN    0.000000           NaN   ...
# 27              NaN            NaN   74.336400           NaN   ...
# 28              NaN            NaN    0.000000           NaN   ...
# 29              NaN            NaN   36.681000           NaN   ...
# ...             ...            ...         ...           ...   ...
# 35469   3953.529400     483.349600    9.589000   6491.176600   ...
# 35470    571.847333    1119.931167  132.624500   6370.265833   ...
# 35471   9785.088800       0.000000   91.992800  14832.721400   ...
# 35472    679.783000       0.000000   26.620600   1215.869200   ...
# 35473   2322.822000       0.000000   11.455800   3865.477800   ...
# 35474   2507.890000       0.000000    9.862200   3441.390800   ...
# 35475   2395.038500       0.000000  157.821500   6401.526750   ...
# 35476   1926.080000       0.000000  198.716000   2532.796000   ...
# 35477      0.000000       7.416667  240.361167    810.535667   ...
# 35478   1928.784400       0.000000  105.050800   3452.226800   ...
# 35479   1993.666667       0.000000   76.033667   3696.297333   ...
# 35480    861.976167     430.977500   33.631000   2246.081167   ...
# 35481   4312.696600    1519.555400  155.008000   8142.189600   ...
# 35482   2427.857600    1184.537800  334.915800   7695.828200   ...
# 35483    498.856600     167.375600    0.000000   1189.278200   ...
# 35484    717.654400     331.129000  191.034800   2066.334800   ...
# 35485    366.985571       0.000000  281.823143   1792.321571   ...
# 35486   2750.000000     650.000000   84.181000   4816.885200   ...
# 35487    694.802000     319.385500  185.153500   2694.626000   ...
# 35488    819.224000       0.000000   45.235000   1465.141200   ...
# 35489   2447.656600     143.154600   28.059800   3224.783600   ...
# 35490    881.495400    1224.513600   15.411000   3259.667000   ...
# 35491   1854.775200       0.000000    0.002000   5268.093800   ...
# 35492   1511.998000    1608.562200   51.281000   5569.559200   ...
# 35493    111.227200      99.765800    9.405400    628.598400   ...
# 35494    311.250000      79.732167   68.475500   1125.875167   ...
# 35495   1113.912167       0.000000   30.706000   2088.400667   ...
# 35496   5974.992167       0.000000  256.749167   7969.523333   ...
# 35497    330.676200       0.000000   92.272000   1088.502600   ...
# 35498    535.985600     131.923400   29.344200   2403.021000   ...
#
#           SAL_PCT  TOTAL_CURR_PCT  TOTAL_SEC_PCT  TOTAL_ALT1_PCT  \
# 0        5.463800        5.417400            NaN             NaN
# 1       15.149200       21.200800            NaN             NaN
# 2       17.113200       19.839200            NaN             NaN
# 3        8.973200        9.453800            NaN             NaN
# 4        1.966750       11.346750            NaN             NaN
# 5       17.647800       14.583200            NaN             NaN
# 6        2.015750      -12.789375            NaN             NaN
# 7       -9.144750       27.624750            NaN             NaN
# 8        4.878200        5.974000            NaN             NaN
# 9       14.028000       47.969000            NaN             NaN
# 10       5.570000      -11.669333            NaN             NaN
# 11     -10.819400       18.779400            NaN             NaN
# 12      10.456000       10.767500            NaN             NaN
# 13      15.542400        6.927000            NaN             NaN
# 14     120.097500       78.398500            NaN             NaN
# 15     522.201400     1694.293600            NaN             NaN
# 16       4.534200       39.544200            NaN             NaN
# 17       9.165125        1.876250            NaN             NaN
# 18       9.867286      -16.459714            NaN             NaN
# 19       8.508333       -5.423833            NaN             NaN
# 20       4.482833      158.067833            NaN             NaN
# 21            NaN             NaN            NaN             NaN
# 22       6.860000        6.860000            NaN             NaN
# 23      -2.451200       44.606167            NaN             NaN
# 24       8.447000        2.490200            NaN             NaN
# 25     253.336600      240.905800            NaN             NaN
# 26       3.484250      -43.319500            NaN             NaN
# 27      82.249000      124.795750            NaN             NaN
# 28      25.873000       13.003500            NaN             NaN
# 29      -3.697714      -45.057571            NaN             NaN
# ...           ...             ...            ...             ...
# 35469    2.855750        2.838750       1.531000        1.531000
# 35470   -0.020200       -0.020200      35.579600       10.506400
# 35471    3.750200        3.750200      15.401600       15.401600
# 35472    1.325400        1.325400       6.451200        6.451200
# 35473    6.573200        0.042800      37.366000       14.926000
# 35474    0.000000       -0.058400      32.561800       18.868600
# 35475    4.411750       -6.918000       7.715250        7.715250
# 35476    0.598000        5.143500      27.552500       20.014250
# 35477    4.830167        4.830167     -24.333833      -26.864400
# 35478    5.395750       -4.538500       8.980500        8.980500
# 35479    2.666667        3.274000     251.957333       -0.040667
# 35480    4.924500        0.736833      -1.279333       -3.938800
# 35481    3.245400      -22.478200      -9.278000      -25.550000
# 35482   14.690000       14.690000      21.406200       -4.886800
# 35483    2.997333        2.997333       2.454333        2.454333
# 35484    3.918400        4.436600      13.056400        9.813000
#      YELP            NaN           NaN         NaN          NaN         NaN
#      YEXT            NaN           NaN         NaN          NaN         NaN
#      YRCW            NaN           NaN         NaN          NaN         NaN
#      YUM             NaN           NaN         NaN          NaN         NaN
#      Z               NaN           NaN         NaN          NaN         NaN
#      ZAGG            NaN           NaN         NaN          NaN         NaN
#      ZAYO            NaN           NaN         NaN          NaN         NaN
#      ZBH             NaN           NaN         NaN          NaN         NaN
#      ZBRA            NaN           NaN         NaN          NaN         NaN
#      ZEN             NaN           NaN         NaN          NaN         NaN
#      ZEUS            NaN           NaN         NaN          NaN         NaN
#      ZFGN            NaN           NaN         NaN          NaN         NaN
#      ZION            NaN           NaN         NaN          NaN         NaN
#      ZIOP            NaN           NaN         NaN          NaN         NaN
#      ZIXI            NaN           NaN         NaN          NaN         NaN
#      ZNGA            NaN           NaN         NaN          NaN         NaN
#      ZS              NaN           NaN         NaN          NaN         NaN
#      ZTS             NaN           NaN         NaN          NaN         NaN
#      ZUMZ            NaN           NaN         NaN          NaN         NaN
#
# [64637 rows x 16 columns]

# %%
#execucomp_panel[['ni','revt']] = execucomp_panel[['ni','revt']]/1000
#execucomp_panel['mktcap'] = execucomp_panel['mktcap']*1000
#execucomp_panel['IO'] = execucomp_panel['IO'] * 100
execucomp_panel['IO_count'] = IO_sum_sum['count']

# %%
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

# %%
Y_variable = ['salary','bonus','Stock_award','Option_award','TDC1']#,'LTIP','Restricted']
X1 = ['IO_count']
X2 = ['IO_count','ni','revt','mktcap']

info_dict={'R-squared' : lambda x: f"{x.rsquared:.2f}",
           'No. observations' : lambda x: f"{int(x.nobs):d}"}

reg_list = []
for y in Y_variable:
    reg_list.append(smf.ols(y+'~ IO_count + C(fyear)', data = execucomp_panel).fit())
    reg_list.append(smf.ols(y+'~ IO_count + ni + revt + mktcap + C(fyear)', data = execucomp_panel).fit())

results_table = summary_col(results=reg_list,
                            float_format='%0.2f',
                            stars = True,
                            model_names=['Salary',
                                         'Salary',
                                         'Bonus',
                                        'Bonus',
                                        'Stock_award','Stock_award',
                                        'Option_award','Option_award',
                                        'Total','Total'],
                            info_dict=info_dict,
                            regressor_order=['const',
                                             'IO_count',
                                             'ni',
                                             'revt',
                                             'mktcap'])

# %%
results_table.add_title('OLS Regressions: Executive Compensation on Institutional Ownership')
print(results_table.as_latex())
# Out:
# \begin{table}
# \caption{OLS Regressions: Executive Compensation on Institutional Ownership} \\
# \begin{center}
# \begin{tabular}{lcccccccccc}
# \hline
#                  &  Salary I & Salary II &  Bonus I   &  Bonus II  & Stock\_award I & Stock\_award II & Option\_award I & Option\_award II &   Total I   &   Total II   \\
# \hline
# \hline
# \end{tabular}
# \begin{tabular}{lllllllllll}
# IO\_count        & 0.49***   & 0.50***   & 0.60***    & 0.24***    & 3.21***        & 1.59***         & 1.37***         & 1.51***          & 7.27***     & 5.40***      \\
#                  & (0.00)    & (0.01)    & (0.02)     & (0.03)     & (0.04)         & (0.06)          & (0.03)          & (0.06)           & (0.07)      & (0.11)       \\
# C(fyear)[T.2018] & 67.56***  & 75.15***  & -462.66*** & -411.71*** & 201.77         & 266.91          & -338.60**       & -386.59**        & -1824.91*** & -1678.44***  \\
#                  & (23.49)   & (23.20)   & (88.55)    & (87.94)    & (175.88)       & (170.24)        & (155.98)        & (155.78)         & (390.79)    & (387.40)     \\
# Intercept        & 257.39*** & 257.07*** & 254.61***  & 291.69***  & 110.63***      & 375.13***       & 21.99           & -5.09            & 1918.92***  & 2075.11***   \\
#                  & (5.14)    & (5.11)    & (19.39)    & (19.35)    & (20.00)        & (21.08)         & (17.74)         & (19.28)          & (85.75)     & (85.44)      \\
# R-squared        & 0.42      & 0.43      & 0.10       & 0.11       & 0.33           & 0.37            & 0.09            & 0.10             & 0.32        & 0.34         \\
# No. observations & 23795     & 23789     & 23795      & 23789      & 16247          & 16243           & 16247           & 16243            & 23678       & 23672        \\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %% [markdown]
# OLS for BoardEx

# %%
BoardEx_comp_avg_public = pd.read_excel('BoardEx_use.xlsx')

BoardEx_comp_avg_public['Year'] = BoardEx_comp_avg_public['AnnualReportDate'].apply(lambda x:parse(str(x)[:4]))

# %%
BoardEx_comp_avg_public['year'] = pd.DatetimeIndex(BoardEx_comp_avg_public['Year']).year
BoardEx_use = BoardEx_comp_avg_public.groupby(['year','Ticker']).first()

# %%
boardex_panel = russell_cov_fix

# %%
boardex_panel[['Salary','Bonus','LTIP','Option','Total']] = BoardEx_use[['Salary','Bonus','LTIPValue','EstValOptHeld','TotalCompensation']]
boardex_panel[['ni','revt','mktcap']] = boardex_panel[['ni','revt','mktcap']]/1000
#execucomp_panel['mktcap'] = execucomp_panel['mktcap']*1000

# %%
Y_variable = ['Salary','Bonus','LTIP','Option','Total']#,'LTIP','Restricted']

info_dict={'R-squared' : lambda x: f"{x.rsquared:.2f}",
           'No. observations' : lambda x: f"{int(x.nobs):d}"}

reg_list = []
for y in Y_variable:
    reg_list.append(smf.ols(y+'~ IO_count + C(fyear)', data = boardex_panel).fit())
    reg_list.append(smf.ols(y+'~ IO_count + ni + revt + mktcap + C(fyear)', data = boardex_panel).fit())

results_table = summary_col(results=reg_list,
                            float_format='%0.2f',
                            stars = True,
                            model_names=['Salary',
                                         'Salary',
                                         'Bonus',
                                        'Bonus',
                                        'LTIP','LTIP',
                                        'Option','Option',
                                        'Total','Total'],
                            info_dict=info_dict,
                            regressor_order=['const',
                                             'IO_count',
                                             'ni',
                                             'revt',
                                             'mktcap'])

# %%
print(results_table.as_latex())
# Out:
# \begin{table}
# \caption{}
# \begin{center}
# \begin{tabular}{lcccccccccc}
# \hline
#                  &  Salary I & Salary II &  Bonus I   &  Bonus II &    LTIP I   &  LTIP II   &   Option I   &  Option II   &  Total I   &  Total II   \\
# \hline
# \hline
# \end{tabular}
# \begin{tabular}{lllllllllll}
# IO\_count        & 0.07***   & 0.05***   & 2.46***    & 1.94***   & 1.77***     & 1.37***    & 51.27***     & 36.63***     & 0.20***    & 0.11***     \\
#                  & (6.20)    & (6.30)    & (411.91)   & (415.53)  & (606.77)    & (614.80)   & (6537.70)    & (6641.66)    & (24.22)    & (24.57)     \\
# C(fyear)[T.2018] & 41.01***  & 45.33***  & -1809.28** & -1544.40* & -849.32     & -743.71    & -22681.88*   & -17674.92    & -198.98*** & -178.10***  \\
#                  & (12.28)   & (12.29)   & (906.39)   & (908.59)  & (1045.47)   & (1047.83)  & (13119.44)   & (13139.82)   & (47.96)    & (47.93)     \\
# Intercept        & 106.93*** & 109.54*** & 513.94***  & 601.57*** & 2039.63***  & 2105.57*** & 32630.01***  & 33075.95***  & 236.45***  & 249.06***   \\
#                  & (3.93)    & (3.96)    & (130.72)   & (133.12)  & (470.73)    & (472.95)   & (4026.99)    & (4044.09)    & (15.36)    & (15.44)     \\
# R-squared        & 0.17      & 0.17      & 0.09       & 0.09      & 0.01        & 0.01       & 0.05         & 0.06         & 0.04       & 0.04        \\
# No. observations & 7676      & 7673      & 3798       & 3795      & 5976        & 5976       & 6859         & 6856         & 7676       & 7673        \\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %%
IO_sum_sum.to_excel('IO_sum.xlsx')

# %%
boardex_panel.to_excel('Boardex_OLS.xlsx')

# %%
execucomp_panel.to_excel('Execucomp_OLS.xlsx')

# %% [markdown]
# Read data for marketcap

# %%
mktcap_file = './Marketcap May'
mktcap_filename = os.listdir(mktcap_file)

# %%
MktCap_may = pd.DataFrame(columns = ['TICKER','Year','MarketCap','Rank'])
for file in mktcap_filename:
    temp = pd.read_csv(os.path.join(os.getcwd(), mktcap_file, file))
    temp['MarketCap'] = temp['PRC']*temp['SHROUT']
    temp['Year'] = parse(file[:4]).year
    temp['Rank'] = temp['MarketCap'].rank(ascending = False)
    MktCap_may = MktCap_may.append(temp[['TICKER','Year','MarketCap','Rank']])

# %%
MktCap_may.to_excel('MktCap_may.xlsx')

# %%
MktCap_may['Year'] = MktCap_may['Year'].astype(int)
MktCap_may_indexed = MktCap_may.groupby(['TICKER','Year']).first()

# %%
Russell_all['R1000'] = Russell_all['Membership'] == 'R1000'

# %%
#Russell_all['Ticker'] = Russell_all['Ticker'].apply(lambda x: x[:-1])

# %%
Russell_all['year'] = Russell_all['Year'].apply(lambda x: parse(x).year)
Russell_all['year'] = Russell_all['year'].astype(int)
#MktCap_may_indexed.loc[['ZUMZ',]]

# %%
MktCap_may_indexed['R1000'] = Russell_all.groupby(['Ticker','year']).first()['R1000']

# %%
Russell_all['Ticker']
MktCap_may['TICKER'].unique().shape
# Out:
# (7095,)

# %%
MktCap_may_indexed['R1000'] = MktCap_may_indexed['R1000'].astype(float)

# %%
MktCap_may_indexed.groupby('Rank').mean().loc[500:1500]['R1000'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
MktCap_may_all = MktCap_may_indexed.reset_index()

MktCap_may_all[MktCap_may_all['Year'] < 2007].groupby('Rank').mean().loc[500:1500].reset_index().plot(kind = 'scatter', x='Rank',y='R1000')
MktCap_may_all[MktCap_may_all['Year'] >= 2007].groupby('Rank').mean().loc[500:1500].reset_index().plot(kind = 'scatter', x='Rank',y='R1000')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
